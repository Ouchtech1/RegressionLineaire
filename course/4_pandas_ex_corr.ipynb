# %% [markdown]
# # [Exercices] Premier pas avec `pandas`

# %% [markdown]
# # [Ex. 1]
#
#
# ##### On s'intéresse au fichier disponible à : `data/co2-data/owid-co2-data.csv`
#
# - 1 - Lire le fichier
# - 2 - S'assurer de la cohérence du type de chaque colonne
# - 3 - Classer les pays par émissions totales de CO2 (= colonne `co2`) par ordre décroissant (quelle est l'unité de la variable CO2 ?). On pourra classer les pays seulement sur 2018.
# - 4 - Classer les pays par PIB (= colonne `gdp`) par ordre décroissant. (quelle est l'unité de la variable PIB ?)
# - 5 - Classer les pays par CO2 / PIB par ordre décroissant.
# - 6 - Réaliser les top 25 pour ces 3 classements
# - 7 - Quels pays apparraissent dans deux top ?
# - 8 - Dans 3 tops ?

# %%
import pandas as pd
# 1 
df = pd.read_csv("../data/co2-data/owid-co2-data.csv")

# %% [markdown]
# #### question 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46523 entries, 0 to 46522
# Data columns (total 74 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    46523 non-null  object
#  1   year                                       46523 non-null  int64
#  2   iso_code                                   39862 non-null  object
#  3   population                                 38574 non-null  float64
#  4   gdp                                        14551 non-null  float64
#  5   cement_co2                                 24974 non-null  float64
#  6   cement_co2_per_capita                      22714 non-null  float64
#  7   co2                                        31349 non-null  float64
#  8   co2_growth_abs                             28944 non-null  float64
#  9   co2_growth_prct                            25032 non-null  float64
#  10  co2_including_luc                          24212 non-null  float64
#  11  co2_including_luc_growth_abs               23909 non-null  float64
#  12  co2_including_luc_growth_prct              24129 non-null  float64
#  13  co2_including_luc_per_capita               23690 non-null  float64
#  14  co2_including_luc_per_gdp                  15701 non-null  float64
#  15  co2_including_luc_per_unit_energy          9528 non-null   float64
#  16  co2_per_capita                             26915 non-null  float64
#  17  co2_per_gdp                                16291 non-null  float64
#  18  co2_per_unit_energy                        10054 non-null  float64
#  19  coal_co2                                   25069 non-null  float64
#  20  coal_co2_per_capita                        24421 non-null  float64
#  21  consumption_co2                            4600 non-null   float64
#  22  consumption_co2_per_capita                 4227 non-null   float64
#  23  consumption_co2_per_gdp                    3898 non-null   float64
#  24  cumulative_cement_co2                      24873 non-null  float64
#  25  cumulative_co2                             29356 non-null  float64
#  26  cumulative_co2_including_luc               24212 non-null  float64
#  27  cumulative_coal_co2                        24968 non-null  float64
#  28  cumulative_flaring_co2                     24774 non-null  float64
#  29  cumulative_gas_co2                         24842 non-null  float64
#  30  cumulative_luc_co2                         39388 non-null  float64
#  31  cumulative_oil_co2                         24941 non-null  float64
#  32  cumulative_other_co2                       2386 non-null   float64
#  33  energy_per_capita                          9987 non-null   float64
#  34  energy_per_gdp                             7159 non-null   float64
#  35  flaring_co2                                24875 non-null  float64
#  36  flaring_co2_per_capita                     24272 non-null  float64
#  37  gas_co2                                    24943 non-null  float64
#  38  gas_co2_per_capita                         24340 non-null  float64
#  39  ghg_excluding_lucf_per_capita              6119 non-null   float64
#  40  ghg_per_capita                             6119 non-null   float64
#  41  land_use_change_co2                        39388 non-null  float64
#  42  land_use_change_co2_per_capita             36026 non-null  float64
#  43  methane                                    6150 non-null   float64
#  44  methane_per_capita                         6120 non-null   float64
#  45  nitrous_oxide                              6150 non-null   float64
#  46  nitrous_oxide_per_capita                   6120 non-null   float64
#  47  oil_co2                                    25042 non-null  float64
#  48  oil_co2_per_capita                         24367 non-null  float64
#  49  other_co2_per_capita                       2386 non-null   float64
#  50  other_industry_co2                         2386 non-null   float64
#  51  primary_energy_consumption                 10085 non-null  float64
#  52  share_global_cement_co2                    20830 non-null  float64
#  53  share_global_co2                           29356 non-null  float64
#  54  share_global_co2_including_luc             24212 non-null  float64
#  55  share_global_coal_co2                      24968 non-null  float64
#  56  share_global_cumulative_cement_co2         20830 non-null  float64
#  57  share_global_cumulative_co2                29356 non-null  float64
#  58  share_global_cumulative_co2_including_luc  24212 non-null  float64
#  59  share_global_cumulative_coal_co2           24968 non-null  float64
#  60  share_global_cumulative_flaring_co2        15980 non-null  float64
#  61  share_global_cumulative_gas_co2            21990 non-null  float64
#  62  share_global_cumulative_luc_co2            39388 non-null  float64
#  63  share_global_cumulative_oil_co2            23421 non-null  float64
#  64  share_global_cumulative_other_co2          2386 non-null   float64
#  65  share_global_flaring_co2                   15980 non-null  float64
#  66  share_global_gas_co2                       21990 non-null  float64
#  67  share_global_luc_co2                       39388 non-null  float64
#  68  share_global_oil_co2                       23421 non-null  float64
#  69  share_global_other_co2                     2386 non-null   float64
#  70  total_ghg                                  6149 non-null   float64
#  71  total_ghg_excluding_lucf                   6149 non-null   float64
#  72  trade_co2                                  4259 non-null   float64
#  73  trade_co2_share                            4258 non-null   float64
# dtypes: float64(71), int64(1), object(2)
# memory usage: 26.3+ MB

# %% [markdown]
# #### question 3

# %%
# Filtrer sur 2018
# df = df[df.year==2018]

# Syntaxe équivalente à : 

# Je crée une série avec autant de valeurs qu'il n'y a de lignes dans la DataFrame
mask = df.year==2018
# On garde les lignes pour lesquelles la valeur du mask vaut True
# Les valeurs de mask qui valent True 
# correspondent à des lignes ou l'année est égale à 2018
df = df[mask]

# %%
# CO2 = 305 donc forcément => Millions de Tonnes (car 67*4.4=294.8)
df[(df.country=="France")][["country", "co2"]]
# Out:
#       country      co2
# 15685  France  322.527

# %%
# Pour les regroupements de pays, pas de iso_code
df.sort_values("co2", ascending=False).head(3)
# Out:
#               country  year iso_code    population           gdp  cement_co2  \
# 46003           World  2018      NaN  7.683790e+09  1.136302e+14    1569.218
# 30254  Non-OECD (GCP)  2018      NaN           NaN           NaN         NaN
# 2825             Asia  2018      NaN  4.588803e+09           NaN    1260.604
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 46003                  0.204  36826.508         729.772            2.022  ...
# 30254                    NaN  22945.100             NaN              NaN  ...
# 2825                   0.275  20437.713         598.067            3.015  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 46003                            100.000                   100.000
# 30254                                NaN                       NaN
# 2825                              57.756                    29.528
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 46003               100.000               100.000               100.000
# 30254                   NaN                   NaN                   NaN
# 2825                 39.276                51.124                38.714
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 46003                 100.000  49368.039                 47980.469     -0.004
# 30254                     NaN        NaN                       NaN        NaN
# 2825                   66.421  25456.090                 25238.279  -1360.064
#
#        trade_co2_share
# 46003           -0.000
# 30254              NaN
# 2825            -6.655
#
# [3 rows x 74 columns]

# %%
# Filtrer sur les lignes qui ont un iso_code renseigné
# On garde les lignes qui ont iso_code qui n'est PAS une valeur nulle
# ~ = 'not vectorisé' 
df = df[~df.iso_code.isnull()]

df.sort_values("co2", ascending=False).head(20)
# Out:
#               country  year iso_code    population           gdp  cement_co2  \
# 8987            China  2018      CHN  1.417069e+09  1.815162e+13     786.745
# 44219   United States  2018      USA  3.321400e+08  1.814065e+13      38.971
# 20134           India  2018      IND  1.369003e+09  8.835758e+12     138.965
# 35051          Russia  2018      RUS  1.456523e+08  3.613410e+12      20.091
# 21754           Japan  2018      JPN  1.262559e+08  4.867011e+12      26.183
# 16792         Germany  2018      DEU  8.289670e+07  3.885961e+12      13.228
# 20550            Iran  2018      IRN  8.561756e+07  1.398996e+12      19.091
# 39257     South Korea  2018      KOR  5.167690e+07  1.958392e+12      24.702
# 36662    Saudi Arabia  2018      SAU  3.501813e+07  1.677339e+12      25.135
# 20306       Indonesia  2018      IDN  2.670668e+08  3.075456e+12      30.832
# 7955           Canada  2018      CAN  3.703526e+07  1.669402e+12       6.915
# 6426           Brazil  2018      BRA  2.101666e+08  2.965402e+12      19.342
# 27008          Mexico  2018      MEX  1.240139e+08  2.006600e+12      20.864
# 38641    South Africa  2018      ZAF  5.733963e+07  6.732722e+11       5.466
# 42585          Turkey  2018      TUR  8.280930e+07  1.655984e+12      39.413
# 3541        Australia  2018      AUS  2.497923e+07  1.238560e+12       2.942
# 43997  United Kingdom  2018      GBR  6.643300e+07  2.540210e+12       4.364
# 21410           Italy  2018      ITA  5.987743e+07  2.077209e+12       7.757
# 33915          Poland  2018      POL  3.852146e+07  1.053479e+12       7.655
# 22274      Kazakhstan  2018      KAZ  1.853810e+07  4.637205e+11       3.891
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 8987                   0.555  10353.877         342.770            3.424  ...
# 44219                  0.117   5376.657         165.700            3.180  ...
# 20134                  0.102   2600.447         165.578            6.800  ...
# 35051                  0.138   1700.453          46.299            2.799  ...
# 21754                  0.207   1143.412         -44.947           -3.782  ...
# 16792                  0.160    754.408         -31.208           -3.972  ...
# 20550                  0.223    700.938          15.536            2.267  ...
# 39257                  0.478    670.169          15.631            2.388  ...
# 36662                  0.718    626.191         -17.447           -2.711  ...
# 20306                  0.115    603.657          36.402            6.417  ...
# 7955                   0.187    584.369          12.825            2.244  ...
# 6426                   0.092    477.102         -20.311           -4.083  ...
# 27008                  0.168    475.269           9.648            2.072  ...
# 38641                  0.095    435.237          -4.143           -0.943  ...
# 42585                  0.476    422.569          -7.651           -1.779  ...
# 3541                   0.118    416.284           1.926            0.465  ...
# 43997                  0.066    379.730          -7.637           -1.972  ...
# 21410                  0.130    349.005          -3.730           -1.058  ...
# 33915                  0.199    337.048          -0.686           -0.203  ...
# 22274                  0.210    331.821          11.029            3.438  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 8987                              49.848                     0.813
# 44219                             15.370                    17.662
# 20134                                NaN                     0.604
# 35051                              5.772                    11.996
# 21754                              3.144                     0.103
# 16792                              3.079                     0.487
# 20550                                NaN                     7.871
# 39257                              2.071                     0.000
# 36662                                NaN                     1.052
# 20306                                NaN                     0.958
# 7955                               0.938                     3.773
# 6426                               1.713                     4.248
# 27008                                NaN                     1.786
# 38641                                NaN                     0.014
# 42585                              1.402                     0.042
# 3541                               1.162                     4.107
# 43997                              1.214                     1.086
# 21410                              1.521                     0.557
# 33915                              1.519                     1.173
# 22274                              0.830                     4.067
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 8987                  7.641                 5.886                12.233
# 44219                21.497                 1.936                19.283
# 20134                 1.676                 3.750                 5.342
# 35051                10.962                 8.962                 3.192
# 21754                 3.107                -0.016                 3.526
# 16792                 2.252                -0.220                 2.162
# 20550                 5.433                -0.570                 1.919
# 39257                 1.556                -0.141                 1.448
# 36662                 3.416                 0.043                 2.768
# 20306                 1.118                26.558                 1.814
# 7955                  3.081                 2.917                 2.176
# 6426                  0.895                21.855                 2.451
# 27008                 2.203                 5.960                 1.906
# 38641                 0.121                -0.035                 0.534
# 42585                 1.268                -0.368                 0.959
# 3541                  1.055                 0.877                 1.172
# 43997                 2.145                 0.126                 1.411
# 21410                 1.908                -1.018                 1.245
# 33915                 0.455                -1.239                 0.706
# 22274                 0.911                -0.275                 0.399
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 8987                   56.711   11821.66                  12471.09   -727.290
# 44219                   8.164    5892.37                   6121.63    428.020
# 20134                     NaN    3360.56                   3388.92   -168.744
# 35051                   5.819    1868.15                   2419.47   -343.469
# 21754                   2.770    1172.32                   1204.37    136.863
# 16792                   2.885     771.48                    800.96    130.370
# 20550                     NaN     925.58                    925.52   -106.350
# 39257                   3.410     669.70                    715.50     52.522
# 36662                     NaN     715.23                    715.23    -24.479
# 20306                     NaN    1692.36                    958.08      9.487
# 7955                    0.716     776.50                    737.99    -51.678
# 6426                    2.113    1434.51                   1046.58      0.940
# 27008                     NaN     669.63                    654.25     50.876
# 38641                     NaN     556.72                    549.65   -122.723
# 42585                   2.246     470.65                    499.29      4.370
# 3541                    1.289     621.28                    617.39    -50.841
# 43997                   1.004     442.48                    453.43    156.052
# 21410                   1.044     385.22                    398.03    102.105
# 33915                   1.599     337.70                    370.61     -8.223
# 22274                   0.946     275.56                    278.54   -149.467
#
#        trade_co2_share
# 8987            -7.024
# 44219            7.961
# 20134           -6.489
# 35051          -20.199
# 21754           11.970
# 16792           17.281
# 20550          -15.173
# 39257            7.837
# 36662           -3.909
# 20306            1.572
# 7955            -8.843
# 6426             0.197
# 27008           10.705
# 38641          -28.197
# 42585            1.034
# 3541           -12.213
# 43997           41.096
# 21410           29.256
# 33915           -2.440
# 22274          -45.045
#
# [20 rows x 74 columns]

# %% [markdown]
# #### question 4

# %%
df = df[~df.gdp.isnull()]
df.sort_values("gdp", ascending=False).head(20)
# Out:
#               country  year iso_code    population           gdp  cement_co2  \
# 8987            China  2018      CHN  1.417069e+09  1.815162e+13     786.745
# 44219   United States  2018      USA  3.321400e+08  1.814065e+13      38.971
# 20134           India  2018      IND  1.369003e+09  8.835758e+12     138.965
# 21754           Japan  2018      JPN  1.262559e+08  4.867011e+12      26.183
# 16792         Germany  2018      DEU  8.289670e+07  3.885961e+12      13.228
# 35051          Russia  2018      RUS  1.456523e+08  3.613410e+12      20.091
# 20306       Indonesia  2018      IDN  2.670668e+08  3.075456e+12      30.832
# 6426           Brazil  2018      BRA  2.101666e+08  2.965402e+12      19.342
# 15685          France  2018      FRA  6.427781e+07  2.581674e+12       6.495
# 43997  United Kingdom  2018      GBR  6.643300e+07  2.540210e+12       4.364
# 21410           Italy  2018      ITA  5.987743e+07  2.077209e+12       7.757
# 27008          Mexico  2018      MEX  1.240139e+08  2.006600e+12      20.864
# 39257     South Korea  2018      KOR  5.167690e+07  1.958392e+12      24.702
# 36662    Saudi Arabia  2018      SAU  3.501813e+07  1.677339e+12      25.135
# 7955           Canada  2018      CAN  3.703526e+07  1.669402e+12       6.915
# 42585          Turkey  2018      TUR  8.280930e+07  1.655984e+12      39.413
# 39621           Spain  2018      ESP  4.679204e+07  1.492300e+12       9.667
# 20550            Iran  2018      IRN  8.561756e+07  1.398996e+12      19.091
# 3541        Australia  2018      AUS  2.497923e+07  1.238560e+12       2.942
# 12085           Egypt  2018      EGY  1.037408e+08  1.221833e+12      21.002
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 8987                   0.555  10353.877         342.770            3.424  ...
# 44219                  0.117   5376.657         165.700            3.180  ...
# 20134                  0.102   2600.447         165.578            6.800  ...
# 21754                  0.207   1143.412         -44.947           -3.782  ...
# 16792                  0.160    754.408         -31.208           -3.972  ...
# 35051                  0.138   1700.453          46.299            2.799  ...
# 20306                  0.115    603.657          36.402            6.417  ...
# 6426                   0.092    477.102         -20.311           -4.083  ...
# 15685                  0.101    322.527         -14.931           -4.424  ...
# 43997                  0.066    379.730          -7.637           -1.972  ...
# 21410                  0.130    349.005          -3.730           -1.058  ...
# 27008                  0.168    475.269           9.648            2.072  ...
# 39257                  0.478    670.169          15.631            2.388  ...
# 36662                  0.718    626.191         -17.447           -2.711  ...
# 7955                   0.187    584.369          12.825            2.244  ...
# 42585                  0.476    422.569          -7.651           -1.779  ...
# 39621                  0.207    270.052          -5.001           -1.818  ...
# 20550                  0.223    700.938          15.536            2.267  ...
# 3541                   0.118    416.284           1.926            0.465  ...
# 12085                  0.202    243.908         -16.203           -6.229  ...
#
#        share_global_cumulative_other_co2  share_global_flaring_co2  \
# 8987                              49.848                     0.813
# 44219                             15.370                    17.662
# 20134                                NaN                     0.604
# 21754                              3.144                     0.103
# 16792                              3.079                     0.487
# 35051                              5.772                    11.996
# 20306                                NaN                     0.958
# 6426                               1.713                     4.248
# 15685                              1.487                     0.705
# 43997                              1.214                     1.086
# 21410                              1.521                     0.557
# 27008                                NaN                     1.786
# 39257                              2.071                     0.000
# 36662                                NaN                     1.052
# 7955                               0.938                     3.773
# 42585                              1.402                     0.042
# 39621                              1.185                     0.921
# 20550                                NaN                     7.871
# 3541                               1.162                     4.107
# 12085                                NaN                     1.035
#
#        share_global_gas_co2  share_global_luc_co2  share_global_oil_co2  \
# 8987                  7.641                 5.886                12.233
# 44219                21.497                 1.936                19.283
# 20134                 1.676                 3.750                 5.342
# 21754                 3.107                -0.016                 3.526
# 16792                 2.252                -0.220                 2.162
# 35051                10.962                 8.962                 3.192
# 20306                 1.118                26.558                 1.814
# 6426                  0.895                21.855                 2.451
# 15685                 1.126                -0.447                 1.544
# 43997                 2.145                 0.126                 1.411
# 21410                 1.908                -1.018                 1.245
# 27008                 2.203                 5.960                 1.906
# 39257                 1.556                -0.141                 1.448
# 36662                 3.416                 0.043                 2.768
# 7955                  3.081                 2.917                 2.176
# 42585                 1.268                -0.368                 0.959
# 39621                 0.822                -0.568                 1.170
# 20550                 5.433                -0.570                 1.919
# 3541                  1.055                 0.877                 1.172
# 12085                 1.364                 0.007                 0.839
#
#        share_global_other_co2  total_ghg  total_ghg_excluding_lucf  trade_co2  \
# 8987                   56.711   11821.66                  12471.09   -727.290
# 44219                   8.164    5892.37                   6121.63    428.020
# 20134                     NaN    3360.56                   3388.92   -168.744
# 21754                   2.770    1172.32                   1204.37    136.863
# 16792                   2.885     771.48                    800.96    130.370
# 35051                   5.819    1868.15                   2419.47   -343.469
# 20306                     NaN    1692.36                    958.08      9.487
# 6426                    2.113    1434.51                   1046.58      0.940
# 15685                   1.338     360.76                    422.74    105.253
# 43997                   1.004     442.48                    453.43    156.052
# 21410                   1.044     385.22                    398.03    102.105
# 27008                     NaN     669.63                    654.25     50.876
# 39257                   3.410     669.70                    715.50     52.522
# 36662                     NaN     715.23                    715.23    -24.479
# 7955                    0.716     776.50                    737.99    -51.678
# 42585                   2.246     470.65                    499.29      4.370
# 39621                   1.022     311.00                    324.88     28.560
# 20550                     NaN     925.58                    925.52   -106.350
# 3541                    1.289     621.28                    617.39    -50.841
# 12085                     NaN     345.01                    344.82     -1.476
#
#        trade_co2_share
# 8987            -7.024
# 44219            7.961
# 20134           -6.489
# 21754           11.970
# 16792           17.281
# 35051          -20.199
# 20306            1.572
# 6426             0.197
# 15685           32.634
# 43997           41.096
# 21410           29.256
# 27008           10.705
# 39257            7.837
# 36662           -3.909
# 7955            -8.843
# 42585            1.034
# 39621           10.576
# 20550          -15.173
# 3541           -12.213
# 12085           -0.605
#
# [20 rows x 74 columns]

# %% [markdown]
# #### question 5

# %%
df["co2/gdp"] = df["co2"] / df["gdp"]

# %%
df.sort_values("co2/gdp", ascending=False).head(20)
# Out:
#                       country  year iso_code    population           gdp  \
# 31142             North Korea  2018      PRK  2.563815e+07  4.051714e+10
# 42241     Trinidad and Tobago  2018      TTO  1.504707e+06  3.469735e+10
# 27560                Mongolia  2018      MNG  3.163994e+06  4.153176e+10
# 22274              Kazakhstan  2018      KAZ  1.853810e+07  4.637205e+11
# 38641            South Africa  2018      ZAF  5.733963e+07  6.732722e+11
# 8987                    China  2018      CHN  1.417069e+09  1.815162e+13
# 23913                   Libya  2018      LBY  6.477791e+06  1.004160e+11
# 43553                 Ukraine  2018      UKR  4.444695e+07  4.313199e+11
# 6082   Bosnia and Herzegovina  2018      BIH  3.400132e+06  4.128632e+10
# 40861                   Syria  2018      SYR  1.933346e+07  5.671062e+10
# 4265                  Bahrain  2018      BHR  1.487346e+06  6.255931e+10
# 46519                Zimbabwe  2018      ZWE  1.505219e+07  2.271535e+10
# 42761            Turkmenistan  2018      TKM  6.065072e+06  1.423910e+11
# 12777                 Estonia  2018      EST  1.322146e+06  3.540942e+10
# 20550                    Iran  2018      IRN  8.561756e+07  1.398996e+12
# 35051                  Russia  2018      RUS  1.456523e+08  3.613410e+12
# 37006                  Serbia  2018      SRB  7.433825e+06  9.997206e+10
# 23569                 Lesotho  2018      LSO  2.198030e+06  5.360396e+09
# 23042                    Laos  2018      LAO  7.105008e+06  4.666696e+10
# 32292                    Oman  2018      OMN  4.601160e+06  1.723582e+11
#
#        cement_co2  cement_co2_per_capita        co2  co2_growth_abs  \
# 31142       2.226                  0.087     47.630          -4.106
# 42241       0.257                  0.171     40.328           0.010
# 27560       0.414                  0.131     45.316          11.180
# 22274       3.891                  0.210    331.821          11.029
# 38641       5.466                  0.095    435.237          -4.143
# 8987      786.745                  0.555  10353.877         342.770
# 23913       1.744                  0.269     54.016           0.579
# 43553       3.719                  0.084    231.675           8.588
# 6082        0.381                  0.112     22.075          -0.081
# 40861       0.751                  0.039     30.230          -2.383
# 4265        0.559                  0.376     32.787          -0.048
# 46519       0.558                  0.037     11.795           2.199
# 42761       1.450                  0.239     73.252          -0.107
# 12777       0.298                  0.225     17.935          -0.827
# 20550      19.091                  0.223    700.938          15.536
# 35051      20.091                  0.138   1700.453          46.299
# 37006       0.869                  0.117     44.320          -1.209
# 23569       0.000                  0.000      2.371          -0.143
# 23042       1.832                  0.258     20.558           0.874
# 32292       1.851                  0.402     72.556           3.936
#
#        co2_growth_prct  ...  share_global_flaring_co2  share_global_gas_co2  \
# 31142           -7.936  ...                     0.000                 0.000
# 42241            0.025  ...                     0.088                 0.475
# 27560           32.753  ...                     0.001                 0.000
# 22274            3.438  ...                     4.067                 0.911
# 38641           -0.943  ...                     0.014                 0.121
# 8987             3.424  ...                     0.813                 7.641
# 23913            1.083  ...                     2.136                 0.233
# 43553            3.849  ...                     0.582                 0.890
# 6082            -0.366  ...                     0.000                 0.006
# 40861           -7.308  ...                     0.325                 0.091
# 4265            -0.146  ...                     0.035                 0.377
# 46519           22.920  ...                     0.000                 0.000
# 42761           -0.145  ...                     0.680                 0.649
# 12777           -4.410  ...                     0.000                 0.013
# 20550            2.267  ...                     7.871                 5.433
# 35051            2.799  ...                    11.996                10.962
# 37006           -2.656  ...                     0.000                 0.065
# 23569           -5.685  ...                     0.000                 0.000
# 23042            4.441  ...                     0.000                 0.000
# 32292            5.736  ...                     1.129                 0.701
#
#        share_global_luc_co2  share_global_oil_co2  share_global_other_co2  \
# 31142                 0.223                 0.024                     NaN
# 42241                -0.007                 0.032                     NaN
# 27560                -0.177                 0.032                     NaN
# 22274                -0.275                 0.399                   0.946
# 38641                -0.035                 0.534                     NaN
# 8987                  5.886                12.233                  56.711
# 23913                -0.011                 0.211                     NaN
# 43553                 0.253                 0.287                   0.928
# 6082                 -0.015                 0.038                     NaN
# 40861                -0.010                 0.174                     NaN
# 4265                  0.000                 0.030                     NaN
# 46519                 0.211                 0.033                     NaN
# 42761                -0.010                 0.164                     NaN
# 12777                -0.031                 0.029                   0.028
# 20550                -0.570                 1.919                     NaN
# 35051                 8.962                 3.192                   5.819
# 37006                -0.277                 0.073                     NaN
# 23569                 0.124                 0.006                     NaN
# 23042                 1.140                 0.027                     NaN
# 32292                 0.009                 0.108                     NaN
#
#        total_ghg  total_ghg_excluding_lucf  trade_co2  trade_co2_share  \
# 31142      76.86                     73.47        NaN              NaN
# 42241      28.81                     28.69    -17.351          -43.025
# 27560      55.74                     52.64     -4.539          -10.017
# 22274     275.56                    278.54   -149.467          -45.045
# 38641     556.72                    549.65   -122.723          -28.197
# 8987    11821.66                  12471.09   -727.290           -7.024
# 23913     121.57                    121.57        NaN              NaN
# 43553     232.76                    244.84    -18.326           -7.910
# 6082       26.01                     27.75        NaN              NaN
# 40861      48.26                     48.25        NaN              NaN
# 4265       51.15                     51.16    -13.458          -41.048
# 46519     118.22                     30.83      0.771            6.537
# 42761     154.97                    154.97        NaN              NaN
# 12777      19.98                     18.03      0.053            0.294
# 20550     925.58                    925.52   -106.350          -15.173
# 35051    1868.15                   2419.47   -343.469          -20.199
# 37006      61.50                     61.59        NaN              NaN
# 23569       2.53                      2.53        NaN              NaN
# 23042      39.26                     29.90      1.724            8.386
# 32292      99.54                     99.52     -9.534          -13.141
#
#             co2/gdp
# 31142  1.175552e-09
# 42241  1.162279e-09
# 27560  1.091117e-09
# 22274  7.155624e-10
# 38641  6.464503e-10
# 8987   5.704106e-10
# 23913  5.379221e-10
# 43553  5.371303e-10
# 6082   5.346807e-10
# 40861  5.330572e-10
# 4265   5.240947e-10
# 46519  5.192523e-10
# 42761  5.144426e-10
# 12777  5.065036e-10
# 20550  5.010293e-10
# 35051  4.705950e-10
# 37006  4.433239e-10
# 23569  4.423181e-10
# 23042  4.405258e-10
# 32292  4.209605e-10
#
# [20 rows x 75 columns]

# %% [markdown]
# ##### Rappel : list comprehension

# %%
res = []
for x in range(10):
    res.append(x**2)
res

res = [x**2 for x in range(10)]
res

res = [(x,y) for x in range(1, 9) for y in range(1, 9)]
res


res = [x**2 for x in range(10) if x%2==0]
res
# Out:
# [0, 4, 16, 36, 64]

# %% [markdown]
# #### Question 6

# %%
# Ces deux lignes sont équivalents
# df.nlargest(25, "co2")["country"].tolist()
# df.sort_values("co2", ascending=False)["country"].tolist()[:25]

# %%
top_25 = {}
for variable in ["co2", "gdp", "co2/gdp"]:
    top_25[variable] = df.nlargest(25, variable)['country'].tolist()

def intersect(la, lb):
    # return [value for value in la if value in lb]
    return list(set(la) & set(lb))

comparison = {}

for variable_a, variable_b in [("co2", "gdp"), ("co2", "co2/gdp"), ("gdp", "co2/gdp")]:   
    comparison[(variable_a, variable_b)] = intersect(top_25[variable_a], top_25[variable_b])

# %%
comparison
# Out:
# {('co2', 'gdp'): ['Brazil',
#   'Thailand',
#   'Russia',
#   'Poland',
#   'United Kingdom',
#   'South Korea',
#   'Saudi Arabia',
#   'Germany',
#   'Spain',
#   'Japan',
#   'United States',
#   'Australia',
#   'Canada',
#   'Taiwan',
#   'India',
#   'Iran',
#   'Italy',
#   'China',
#   'France',
#   'Turkey',
#   'Indonesia',
#   'Mexico'],
#  ('co2', 'co2/gdp'): ['Kazakhstan',
#   'Vietnam',
#   'Russia',
#   'China',
#   'Saudi Arabia',
#   'Iran',
#   'South Africa'],
#  ('gdp', 'co2/gdp'): ['Iran', 'Russia', 'Saudi Arabia', 'China']}

# %% [markdown]
# #### Question 7

# %%
# comparison[('co2', 'gdp')]
# comparison[('co2', 'co2/gdp')]
# comparison[('gdp', 'co2/gdp')]

# %% [markdown]
# #### Question 8

# %%
def intersect(la, lb, lc):
    return list(set(la) & set(lb) & set(lc))

intersect(top_25["co2"], top_25["gdp"], top_25["co2/gdp"])
# Out:
# ['Iran', 'Russia', 'Saudi Arabia', 'China']

# %% [markdown]
# # [Ex. 2] Création de données de tests
#
# ### Question 1
#
# > On veut créer un historique de ventes pour tester le code d'un future site de ecommerce - on peut le résumer dans le fichier CSV suivant :
#
# |        timestamp | customer_id | product_id | quantity | price | revenue |
# |-----------------:|------------:|-----------:|---------:|------:|--------:|
# | 2022/12/27 13:05 |        1986 |       3456 |        4 |     5 |      20 |
# | 2022/12/27 13:05 |        1986 |       3459 |        3 |     6 |      18 |
# | 2022/12/27 13:06 |       24501 |       1242 |        2 |     4 |       8 |
# | 2022/12/27 13:12 |       48285 |       3424 |        4 |    25 |     100 |
# | 2022/12/27 13:14 |        2422 |       3456 |       10 |     5 |      50 |
# |              ... |         ... |        ... |      ... |   ... |     ... |
#
#
# - timestamp (datetime)
# - customer_id (int)
# - product_id (int)
# - quantity (int)
# - price (int)
# - revenue (int)
#
#
# De plus on souhaite que l'historique vérifie les contraintes suivantes :
# - La période va du 2022/07/01 00:00:00 au 2022/12/31 23:59:59 (inclus)
# - 100 000 transactions (lignes)
# - 4000 clients différents
# - 250 produits différents avec un prix moyen de 15 €
# - La quantité moyenne vendue par transaction est de 2.1 unités
# - Un même produit est toujours vendu au même prix
#
# **Créer un tel fichier**
#
# (**en adaptant le code ci-dessous avec les bonnes constantes et en ajoutant les bons imports**)
#
#
# ### Question 2
# On ajoute les contraintes suivantes :
# - Lorsque l'on achète le mardi, on bénéficie d'une remise (crée une colonne discount)
#     - De 5% pour une transaction de 1 à 3 produits
#     - De 10% pour une transaction à partir de 4 produits
# - Les clients sont 50 % à faire au moins une transaction par mois sur tout la période
# - 10 % des clients font une seule transaction sur tout la période
#
#
# **Créer un tel fichier**
#
#
# ### Question 3
# Ecrire une fonction `split_train_test` qui prend en argument une DataFrame `df` et un réel `test_proportion` entre 0 et 1 et renvoie deux DataFrames `train` et `test`, ayant les mêmes colonnes que `df` et se partageant ses lignes (aléatoirement et de manière mutuellement exclusive) avec les proportions `1 - test_portion` et `test_portion`
#
#
# ### Question 4
# Même question, en faisant en sorte que les moyennes des variables quantitatives des deux DataFrames `test` et `train` soient proches de celles des moyennes des variables quantitatives de `df` (moins de 10% d'écart)
#
# ### Question 5
# Même question, en faisant en sorte que les histogrammes des variables quantitatives des deux DataFrames `test` et `train` soient ressemblant à ceux des variables quantitatives de `df` (moins de 10% d'écart)

# %%
import pandas as pd
import numpy as np
import datetime
# Question 1

# La période va du 2022/07/01 00:00:00 au 2022/12/31 23:59:59 (inclus)
# 100 000 transactions (lignes)
# 4000 clients différents
# 250 produits différents avec un prix moyen de 15 €
# La quantité moyenne vendue par transaction est de 2.1 unités
# Un même produit est toujours vendu au même prix


N_PRODUITS = 250
N_CLIENTS = 4_000
N_TRANSACTIONS = 100_000
DATE_START = datetime.date(2022, 7, 1)
DATE_END = datetime.date(2022, 12, 31)


######################################################################
# Fonctions qui génère des données "intelligemment"
######################################################################

def generate_random_price():
    return np.random.choice(
        [12, 14, 15, 16, 17, 18], 
        p=[0.4,0.05,0.1,0.05,0.2, 0.2]
    )


#def generate_random_quantity():
#    return np.random.choice(
#        [1, 2, 3, 4, 5], 
#        p=[0.25,0.55,0.1,0.05,0.05]
#    )

def generate_random_quantity():
    return int(np.abs(np.random.randn() * 4) + 1) 

def generate_random_hour():
    hour_weights = [1/24 / 4 for _ in range(7)] + [1 /24 / 2 for _ in range(12)]  +[0.6770833333333334 / 5 for _ in range(5)]
    return np.random.choice(
        list(range(24)),
        p=hour_weights
    )  

def generate_random_minute():
    return np.random.randint(0, 60)

def generate_random_second():
    return np.random.randint(0, 60)


######################################################################
# Générations des infos qu'on retrouve dans les transactions
######################################################################

# Génére des couples produits et prix
# => Assure que j'aurais le même prix par produit
products = [
    (_id, generate_random_price()) 
    for _id in range(1, N_PRODUITS+1)
]

# On génère les client ids
client_ids = list(range(1, N_CLIENTS+1))

# Pour les dates : 
# Stratégie : piocher une date dans la liste des dates de la période 
# (pas d'a priori sur des dates en particulier, la même proba pour toute)
# On génère l'heure, avec des a priori - cf fonctions ci-dessus
# (Minutes et seconds pas d' a priori)

# Liste des dates
possible_dates = []
date = DATE_START
while date <=  DATE_END:
    possible_dates.append(date)
    date += datetime.timedelta(days=1)

# On vérifie que première et dernières sont les bonnes
print(possible_dates[0])
print(possible_dates[-1])


timestamps = []
for _ in range(10_000):
    # On pioche une date
    date = np.random.choice(possible_dates)
    # On crée la timestamp en combinant
    timestamp = datetime.datetime.combine(
        date, # la date
        datetime.time( # et l'heure (au sens: heure, minute et seconde)
            hour=generate_random_hour(),
            minute=generate_random_minute(),
            second=generate_random_second()
        )
    )
    timestamps.append(timestamp)
    
    
## Showtime


####################################
# DataFrame creation & Timestamp
####################################

# On crée une dataframe avec le bon nombre de ligne 
# (Car c'est le nombre de dates)
df = pd.DataFrame({"timestamp": timestamps})

####################################
# Ajout du client
####################################

# On pioche un client_id par date
df["client_id"] = [np.random.choice(client_ids) for _ in range(len(df))]


####################################
# Ajout infos produits
####################################

# On pioche un produit par date (c'est un TUPLE !!!)
df["product"] = [
    products[np.random.choice(range(len(products)))] for _ in range(len(df))
]
# On extrait le produit_id et le prix
df["produit_id"] = df["product"].map(lambda t: t[0])
df["price"] = df["product"].map(lambda t: t[1])
# On se débarasse de la colonne avec le tuple
df = df.drop("product", axis=1)

####################################
# Ajout de la quantité
####################################
df["quantity"] = [generate_random_quantity() for _ in range(len(df))]

df["revenue"] = df["price"] * df["quantity"]
# Out:
# 2022-07-01
# 2022-12-31

# %%
df.quantity.hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Question 3

# %%
def split_train_test(df, test_proportion):
    test = df.sample(frac=test_proportion)
    train = df[~df.index.isin(test.index)]
    return train, test

# train, test = split_train_test(df, 0.1)

# %% [markdown]
# #### Question 4 / 5 (une seule variable)

# %%
def split_train_test_advanced(df, test_proportion):
    l_train = []
    l_test = []
    for qty_value in df.quantity.unique():
        
        # On filtre sur la quantité
        df_filtered_on_qty = df[df['quantity'] == qty_value]
        
        # Un morceau avec proportion test_proportion
        test_filtered_on_qty = df_filtered_on_qty.sample(frac=test_proportion)
        
        # Le reste pour le train 
        train_filtered_on_qty = df_filtered_on_qty[
            ~df_filtered_on_qty.index.isin(test_filtered_on_qty.index)
        ]
        
        l_test.append(test_filtered_on_qty)
        l_train.append(train_filtered_on_qty)
        
    # Les concaténations respecte les proportions test_proportion 
    # et 1-test_proportion 
    # Car elles sont réunions de morceaux qui respectent tous les proportions
    return pd.concat(l_train), pd.concat(l_test)

train, test = split_train_test(df, 0.5)
train.quantity.mean(), test.quantity.mean()
train.quantity.hist(alpha=0.5)
test.quantity.hist(alpha=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Question 4 / 5 (deux variables)

# %%
import matplotlib.pyplot as plt

def split_train_test_advanced_v2(df, test_proportion):
        
    l_train = []
    l_test = []
    for qty_value in df.quantity.unique():
        
        # On filtre sur la quantité
        df_filtered_on_qty = df[df['quantity'] == qty_value]
        
        for price_value in df_filtered_on_qty.price.unique():
            
            # On filtre sur le prix
            df_filtered_on_price = df_filtered_on_qty[df_filtered_on_qty['price'] == price_value]
        
            # Un morceau avec proportion test_proportion
            test_filtered_on_qty_and_price = df_filtered_on_price.sample(frac=test_proportion)
        
            # Le reste pour le train 
            train_filtered_on_qty_and_price = df_filtered_on_price[
            ~df_filtered_on_price.index.isin(test_filtered_on_qty_and_price.index)
            ]
        
            l_test.append(test_filtered_on_qty_and_price)
            l_train.append(train_filtered_on_qty_and_price)
        
    # Les concaténations respecte les proportions test_proportion 
    # et 1-test_proportion 
    # Car elles sont réunions de morceaux qui respectent tous les proportions
    return pd.concat(l_train), pd.concat(l_test)

train, test = split_train_test(df, 0.5)
print(train.quantity.mean(), test.quantity.mean(), df.quantity.mean())
print(train.price.mean(), test.price.mean(), df.price.mean())
train.quantity.hist(alpha=0.5)
test.quantity.hist(alpha=0.5)
plt.show()
train.price.hist(alpha=0.5)
test.price.hist(alpha=0.5)
# Out:
# 3.7298 3.7118 3.7208
# 14.6954 14.6874 14.6914
# <AxesSubplot:>

# %% [markdown]
# # [Ex. 3 ]
#
# Le fichier `movie_metadata.csv` contient des informations au sujet de 5043 films qui ont été extraites de l'IMDB.
#
# - 1.
#  - a. Quels sont les 10 réalisateurs qui ont le meilleur score (`imdb_score`) moyen ?
#  - b. Quels sont les 10 pays qui ont le meilleur score (`imdb_score`) moyen ?
#
#
# - 2.
#  - a. Créer une colonne par genre (columne `genres` Action, Adventure...) qui faut True si le film a ce genre renseigné et 0 sinon.
#  - b. Calculer le nombre total de films par genre
#  - c. Calculer l'évolution du nombre de films par genre entre 2000 et 2010
#  - d. Calculer l'évolution 'Year to Year' (% d'augmentation entre année N et N+1) du nombre de films pour chaque genre.
#  - e. Faire de même pour chaque pays.
#
#
# - 3. On s'intéresser seulement aux films publiés après 2000.
# - a. Calculer le prix à la minute de chaque film (à partir des colonnes `budget` et `duration`)
# - b. Quels sont tous les acteurs (renseignés dans les colonnes `actor_X_name`) qui ont joué dans les films qui ont un prix à la minute dans les 10% les plus élevés ?
#
#
# - 4.
# - a. Quels sont les réalisateurs dont les films ont la rentabilité moyenne (`gross` / `budget`) la plus élevée ?
#
# ***
#
#
# - 5.
#  - a. Plusieurs utilisateurs de l'IMDB ont reporté que les notes seraient gonflées depuis quelques années. Que peut-on calculer pour essayer de s'en assurer ? Proposer deux méthodes.
#  - b. Implémenter ces deux méthodes.
#
#
# - 6.
#  - a. En calculant des moyennes, en regardant des évolutions, en calculant des proportions ou des tables de contingence... déterminer des conditions qui semblent être associées à des notes plus élevées.
#  - b. Bâtir un modèle de prédiction de la variable `imdb_score` sur la base des autres variables et des données disponibles a priori (ie, pour réaliser la prédiction d'un film sorti en 2010, on peut utiliser toutes les statistiques des films sortis en 2009)
#  (On pourra utiliser seulement les variables #likes sur facebook pour le film, et la durée et filtrer sur les films après 2000 et sur les films des Etats-Unis et du Royaume Uni et reproduire la méthode dans 3_a_... - 9. Un peu de prédiction - 𝑃=𝑎1×𝐶+𝑎2×𝐷 )
#
#
# - 7. On crée un nouvelle variable `is_good_movie` qui vaut True si l`imdb_score` est plus grand que 7 et vaut False sinon.
#
#  - a. En calculant des moyennes, en regardant des évolutions, en calculant des proportions ou des tables de contingence... déterminer des conditions qui semblent être associées à "des bons films".
#  - b. Bâtir un modèle de prédiction de la variable `is_good_movie` sur la base des autres variables et des données disponibles a priori.

# %%
import pandas as pd

df = pd.read_csv("../data/imdb/movie_metadata.csv")



# Question 1
score_mean_per_dir = df.groupby("director_name").imdb_score.mean()

# Example d'accès à une valeur sur la base de l'id de la ligne
print(score_mean_per_dir.loc["Quentin Tarantino"])

score_mean_per_dir.sort_values(ascending=False)[:10]


# Question 2
score_mean_per_country = df.groupby("country").imdb_score.mean()
# exemple
print(score_mean_per_country.loc["France"])
score_mean_per_country.sort_values(ascending=False)[:10]


# Question 2 (pour un seul genre)

# Méthode 1 avec une lambda fonction
df["Action"] = df["genres"].map(lambda string: "Action" in string.split("|"))


# Méthode 2 avec une fonction définie préalablement
def has_action_in_genres(string):
    return "Action" in string.split("|")

df["Action"] = df["genres"].map(has_action_in_genres)

# Question 2 (pour tous les genres)

# On crée la liste avec les sous listes de genres
genres = [ 
    genres.split("|")
    for genres in df["genres"].tolist()
]

# On flatten la liste
genres = [
    genre 
    for genres_sublist in genres
    for genre in genres_sublist
]

# On récupère les valeurs
genres = list(set(genres))

for genre in genres:
    df[genre] = df["genres"].map(lambda string: genre in string.split("|"))
    
df[genres].sum()
# Out:
# 8.2
# 6.678571428571429
# Sci-Fi          616
# Sport           182
# Adventure       923
# War             213
# News              3
# Drama          2594
# Fantasy         610
# Crime           889
# Documentary     121
# Western          97
# Animation       242
# Film-Noir         6
# Action         1153
# Music           214
# Mystery         500
# Horror          565
# Family          546
# Thriller       1411
# History         207
# Comedy         1872
# Game-Show         1
# Biography       293
# Reality-TV        2
# Romance        1107
# Musical         132
# Short             5
# dtype: int64

# %%
for genre in genres:
    movies_2010 = df[(df.title_year==2010) & df[genre]]
    movies_2000 = df[(df.title_year==2000) & df[genre]]

    count_movies_2010 = len(movies_2010)
    count_movies_2000 = len(movies_2000)
    
    if count_movies_2000 ==0:
        print(f"No movies for genre {genre} in 2000")
        continue

    # Autre solution
    # count_action_movies_2010 = action_movies_2010.shape[0]
    # count_action_movies_2000 = action_movies_2000.shape[0]

    # Evolution en pourcent : (nouveau - ancien) / ancien
    # (moyen mnémotechnique : nouveau = (1+evol%) * ancien)
    count_evolution = (count_movies_2010 - count_movies_2000) / count_movies_2000
    print(genre, round(count_evolution * 100, 2), "%")




# set(df["country"])
for country in df["country"].unique():
    for year_delta in range(10):
        movies_n = df[(df.title_year==2000 + year_delta) & (df["country"]==country)]
        movies_nplus1 = df[(df.title_year== 2000 + year_delta + 1) & (df["country"]==country)]

        count_movies_n = len(movies_n)
        count_movies_nplus1 = len(movies_nplus1)

        if count_movies_n ==0:
            print(f"No movies for country {country} in 2000")
            continue

        # Autre solution
        # count_action_movies_2010 = action_movies_2010.shape[0]
        # count_action_movies_2000 = action_movies_2000.shape[0]

        # Evolution en pourcent : (nouveau - ancien) / ancien
        # (moyen mnémotechnique : nouveau = (1+evol%) * ancien)
        count_evolution = (count_movies_nplus1 - count_movies_n) / count_movies_n
        print(
            country, 
            2000+year_delta, 
            "to" , 
            2000+year_delta+1, 
            round(count_evolution * 100, 2), 
            "%"
        )
# Out:
# Sci-Fi 10.53 %
# Sport -44.44 %
# Adventure 19.35 %
# War 250.0 %
# No movies for genre News in 2000
# Drama 30.34 %
# Fantasy 89.47 %
# Crime -16.67 %
# Documentary 250.0 %
# Western 50.0 %
# Animation 30.0 %
# No movies for genre Film-Noir in 2000
# Action 64.71 %
# Music -30.0 %
# Mystery 28.57 %
# Horror 62.5 %
# Family 78.95 %
# Thriller 27.66 %
# History 250.0 %
# Comedy 26.67 %
# No movies for genre Game-Show in 2000
# Biography 57.14 %
# No movies for genre Reality-TV in 2000
# Romance 40.91 %
# Musical 100.0 %
# No movies for genre Short in 2000
# USA 2000 to 2001 9.56 %
# USA 2001 to 2002 5.37 %
# USA 2002 to 2003 -14.01 %
# USA 2003 to 2004 15.56 %
# USA 2004 to 2005 -1.28 %
# USA 2005 to 2006 7.14 %
# USA 2006 to 2007 -8.48 %
# USA 2007 to 2008 7.95 %
# USA 2008 to 2009 12.88 %
# USA 2009 to 2010 -9.24 %
# UK 2000 to 2001 -25.0 %
# UK 2001 to 2002 83.33 %
# UK 2002 to 2003 -72.73 %
# UK 2003 to 2004 250.0 %
# UK 2004 to 2005 9.52 %
# UK 2005 to 2006 -17.39 %
# UK 2006 to 2007 0.0 %
# UK 2007 to 2008 21.05 %
# UK 2008 to 2009 -8.7 %
# UK 2009 to 2010 0.0 %
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country nan in 2000
# No movies for country New Zealand in 2000
# New Zealand 2001 to 2002 0.0 %
# New Zealand 2002 to 2003 -100.0 %
# No movies for country New Zealand in 2000
# No movies for country New Zealand in 2000
# New Zealand 2005 to 2006 -75.0 %
# New Zealand 2006 to 2007 -100.0 %
# No movies for country New Zealand in 2000
# No movies for country New Zealand in 2000
# No movies for country New Zealand in 2000
# No movies for country Canada in 2000
# Canada 2001 to 2002 200.0 %
# Canada 2002 to 2003 50.0 %
# Canada 2003 to 2004 -44.44 %
# Canada 2004 to 2005 100.0 %
# Canada 2005 to 2006 -50.0 %
# Canada 2006 to 2007 20.0 %
# Canada 2007 to 2008 -16.67 %
# Canada 2008 to 2009 80.0 %
# Canada 2009 to 2010 -11.11 %
# Australia 2000 to 2001 0.0 %
# Australia 2001 to 2002 100.0 %
# Australia 2002 to 2003 50.0 %
# Australia 2003 to 2004 -100.0 %
# No movies for country Australia in 2000
# Australia 2005 to 2006 -33.33 %
# Australia 2006 to 2007 -100.0 %
# No movies for country Australia in 2000
# Australia 2008 to 2009 33.33 %
# Australia 2009 to 2010 0.0 %
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# No movies for country Belgium in 2000
# Japan 2000 to 2001 0.0 %
# Japan 2001 to 2002 -100.0 %
# No movies for country Japan in 2000
# No movies for country Japan in 2000
# Japan 2004 to 2005 -100.0 %
# No movies for country Japan in 2000
# No movies for country Japan in 2000
# No movies for country Japan in 2000
# Japan 2008 to 2009 -100.0 %
# No movies for country Japan in 2000
# Germany 2000 to 2001 16.67 %
# Germany 2001 to 2002 -28.57 %
# Germany 2002 to 2003 -40.0 %
# Germany 2003 to 2004 200.0 %
# Germany 2004 to 2005 -33.33 %
# Germany 2005 to 2006 216.67 %
# Germany 2006 to 2007 -78.95 %
# Germany 2007 to 2008 100.0 %
# Germany 2008 to 2009 -25.0 %
# Germany 2009 to 2010 -33.33 %
# No movies for country China in 2000
# No movies for country China in 2000
# China 2002 to 2003 -100.0 %
# No movies for country China in 2000
# China 2004 to 2005 0.0 %
# China 2005 to 2006 200.0 %
# China 2006 to 2007 -100.0 %
# No movies for country China in 2000
# China 2008 to 2009 150.0 %
# China 2009 to 2010 -80.0 %
# France 2000 to 2001 100.0 %
# France 2001 to 2002 12.5 %
# France 2002 to 2003 -44.44 %
# France 2003 to 2004 20.0 %
# France 2004 to 2005 66.67 %
# France 2005 to 2006 -10.0 %
# France 2006 to 2007 -33.33 %
# France 2007 to 2008 0.0 %
# France 2008 to 2009 83.33 %
# France 2009 to 2010 0.0 %
# No movies for country New Line in 2000
# New Line 2001 to 2002 -100.0 %
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# No movies for country New Line in 2000
# Mexico 2000 to 2001 0.0 %
# Mexico 2001 to 2002 0.0 %
# Mexico 2002 to 2003 -100.0 %
# No movies for country Mexico in 2000
# No movies for country Mexico in 2000
# No movies for country Mexico in 2000
# No movies for country Mexico in 2000
# Mexico 2007 to 2008 -100.0 %
# No movies for country Mexico in 2000
# No movies for country Mexico in 2000
# No movies for country Spain in 2000
# No movies for country Spain in 2000
# Spain 2002 to 2003 0.0 %
# Spain 2003 to 2004 100.0 %
# Spain 2004 to 2005 -100.0 %
# No movies for country Spain in 2000
# Spain 2006 to 2007 33.33 %
# Spain 2007 to 2008 -25.0 %
# Spain 2008 to 2009 0.0 %
# Spain 2009 to 2010 -66.67 %
# No movies for country Hong Kong in 2000
# Hong Kong 2001 to 2002 -100.0 %
# No movies for country Hong Kong in 2000
# Hong Kong 2003 to 2004 100.0 %
# Hong Kong 2004 to 2005 -100.0 %
# No movies for country Hong Kong in 2000
# Hong Kong 2006 to 2007 200.0 %
# Hong Kong 2007 to 2008 -66.67 %
# Hong Kong 2008 to 2009 100.0 %
# Hong Kong 2009 to 2010 -100.0 %
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# Czech Republic 2006 to 2007 -100.0 %
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# No movies for country Czech Republic in 2000
# India 2000 to 2001 0.0 %
# India 2001 to 2002 -100.0 %
# No movies for country India in 2000
# No movies for country India in 2000
# India 2004 to 2005 200.0 %
# India 2005 to 2006 33.33 %
# India 2006 to 2007 -50.0 %
# India 2007 to 2008 -50.0 %
# India 2008 to 2009 100.0 %
# India 2009 to 2010 50.0 %
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country Soviet Union in 2000
# No movies for country South Korea in 2000
# No movies for country South Korea in 2000
# No movies for country South Korea in 2000
# South Korea 2003 to 2004 -50.0 %
# South Korea 2004 to 2005 0.0 %
# South Korea 2005 to 2006 0.0 %
# South Korea 2006 to 2007 0.0 %
# South Korea 2007 to 2008 0.0 %
# South Korea 2008 to 2009 0.0 %
# South Korea 2009 to 2010 0.0 %
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Peru in 2000
# No movies for country Italy in 2000
# No movies for country Italy in 2000
# Italy 2002 to 2003 0.0 %
# Italy 2003 to 2004 0.0 %
# Italy 2004 to 2005 -100.0 %
# No movies for country Italy in 2000
# No movies for country Italy in 2000
# Italy 2007 to 2008 -100.0 %
# No movies for country Italy in 2000
# Italy 2009 to 2010 -50.0 %
# No movies for country Russia in 2000
# No movies for country Russia in 2000
# No movies for country Russia in 2000
# Russia 2003 to 2004 0.0 %
# Russia 2004 to 2005 -100.0 %
# No movies for country Russia in 2000
# No movies for country Russia in 2000
# Russia 2007 to 2008 -100.0 %
# No movies for country Russia in 2000
# Russia 2009 to 2010 0.0 %
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# No movies for country Aruba in 2000
# Denmark 2000 to 2001 -100.0 %
# No movies for country Denmark in 2000
# No movies for country Denmark in 2000
# No movies for country Denmark in 2000
# No movies for country Denmark in 2000
# Denmark 2005 to 2006 -100.0 %
# No movies for country Denmark in 2000
# No movies for country Denmark in 2000
# Denmark 2008 to 2009 -100.0 %
# No movies for country Denmark in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Libya in 2000
# No movies for country Ireland in 2000
# No movies for country Ireland in 2000
# No movies for country Ireland in 2000
# Ireland 2003 to 2004 0.0 %
# Ireland 2004 to 2005 -100.0 %
# No movies for country Ireland in 2000
# Ireland 2006 to 2007 100.0 %
# Ireland 2007 to 2008 -100.0 %
# No movies for country Ireland in 2000
# Ireland 2009 to 2010 -100.0 %
# No movies for country South Africa in 2000
# No movies for country South Africa in 2000
# No movies for country South Africa in 2000
# No movies for country South Africa in 2000
# No movies for country South Africa in 2000
# No movies for country South Africa in 2000
# South Africa 2006 to 2007 -100.0 %
# No movies for country South Africa in 2000
# South Africa 2008 to 2009 0.0 %
# South Africa 2009 to 2010 -100.0 %
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# No movies for country Iceland in 2000
# Iceland 2009 to 2010 -100.0 %
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# No movies for country Switzerland in 2000
# Switzerland 2009 to 2010 -100.0 %
# No movies for country Romania in 2000
# No movies for country Romania in 2000
# No movies for country Romania in 2000
# No movies for country Romania in 2000
# Romania 2004 to 2005 -100.0 %
# No movies for country Romania in 2000
# No movies for country Romania in 2000
# Romania 2007 to 2008 -100.0 %
# No movies for country Romania in 2000
# No movies for country Romania in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country West Germany in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Chile in 2000
# No movies for country Netherlands in 2000
# No movies for country Netherlands in 2000
# No movies for country Netherlands in 2000
# No movies for country Netherlands in 2000
# No movies for country Netherlands in 2000
# No movies for country Netherlands in 2000
# Netherlands 2006 to 2007 -100.0 %
# No movies for country Netherlands in 2000
# Netherlands 2008 to 2009 -100.0 %
# No movies for country Netherlands in 2000
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# Hungary 2005 to 2006 -100.0 %
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# No movies for country Hungary in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Panama in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# No movies for country Greece in 2000
# Greece 2009 to 2010 -100.0 %
# No movies for country Sweden in 2000
# No movies for country Sweden in 2000
# Sweden 2002 to 2003 -100.0 %
# No movies for country Sweden in 2000
# Sweden 2004 to 2005 -100.0 %
# No movies for country Sweden in 2000
# No movies for country Sweden in 2000
# Sweden 2007 to 2008 -100.0 %
# No movies for country Sweden in 2000
# No movies for country Sweden in 2000
# No movies for country Norway in 2000
# Norway 2001 to 2002 -100.0 %
# No movies for country Norway in 2000
# No movies for country Norway in 2000
# No movies for country Norway in 2000
# No movies for country Norway in 2000
# No movies for country Norway in 2000
# No movies for country Norway in 2000
# No movies for country Norway in 2000
# Norway 2009 to 2010 0.0 %
# Taiwan 2000 to 2001 -100.0 %
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Taiwan in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Official site in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Cambodia in 2000
# No movies for country Thailand in 2000
# Thailand 2001 to 2002 -100.0 %
# No movies for country Thailand in 2000
# No movies for country Thailand in 2000
# No movies for country Thailand in 2000
# Thailand 2005 to 2006 -100.0 %
# No movies for country Thailand in 2000
# No movies for country Thailand in 2000
# Thailand 2008 to 2009 -100.0 %
# No movies for country Thailand in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# No movies for country Slovakia in 2000
# Slovakia 2008 to 2009 -100.0 %
# No movies for country Slovakia in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# No movies for country Bulgaria in 2000
# Iran 2000 to 2001 -100.0 %
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Iran in 2000
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# Poland 2006 to 2007 -100.0 %
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# No movies for country Poland in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Georgia in 2000
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# Turkey 2006 to 2007 -100.0 %
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# No movies for country Turkey in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Nigeria in 2000
# No movies for country Brazil in 2000
# No movies for country Brazil in 2000
# Brazil 2002 to 2003 -100.0 %
# No movies for country Brazil in 2000
# No movies for country Brazil in 2000
# Brazil 2005 to 2006 -100.0 %
# No movies for country Brazil in 2000
# Brazil 2007 to 2008 -100.0 %
# No movies for country Brazil in 2000
# No movies for country Brazil in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Finland in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# No movies for country Bahamas in 2000
# Argentina 2000 to 2001 -100.0 %
# No movies for country Argentina in 2000
# No movies for country Argentina in 2000
# No movies for country Argentina in 2000
# Argentina 2004 to 2005 -100.0 %
# No movies for country Argentina in 2000
# No movies for country Argentina in 2000
# No movies for country Argentina in 2000
# No movies for country Argentina in 2000
# Argentina 2009 to 2010 -100.0 %
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# Colombia 2004 to 2005 -100.0 %
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# No movies for country Colombia in 2000
# No movies for country Israel in 2000
# No movies for country Israel in 2000
# No movies for country Israel in 2000
# No movies for country Israel in 2000
# No movies for country Israel in 2000
# No movies for country Israel in 2000
# Israel 2006 to 2007 -100.0 %
# No movies for country Israel in 2000
# Israel 2008 to 2009 -100.0 %
# No movies for country Israel in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Egypt in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Kyrgyzstan in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Indonesia in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Pakistan in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Slovenia in 2000
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# Afghanistan 2003 to 2004 -100.0 %
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# No movies for country Afghanistan in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Dominican Republic in 2000
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# Cameroon 2005 to 2006 -100.0 %
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# No movies for country Cameroon in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country United Arab Emirates in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Kenya in 2000
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000
# Philippines 2005 to 2006 -100.0 %
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000
# No movies for country Philippines in 2000

# %%
df = df[df.title_year >= 2010]

df["profitability"] = df.gross / df.budget
# df[df.profitability<100].profitability.hist(bins=100)



profitable_directors = df.sort_values("profitability", ascending=False)\
                         .director_name[:50]\
                         .unique()

print(len(profitable_directors))
# Out:
# 44

# %%
mean_profitabilities = {}

for director_name in df.director_name.unique():
    # Subset
    subset = df[df.director_name==director_name][["movie_title", "profitability"]].copy()
    # Moyenne
    mean_profitabilities[director_name] = subset.profitability.mean()

alamano = pd.Series(mean_profitabilities)

avecpandas = df.groupby("director_name").profitability.mean()
pd.DataFrame(alamano).join(pd.DataFrame(avecpandas))
# Out:
#                            0  profitability
# Sam Mendes          1.286744       1.286744
# Christopher Nolan   1.586807       1.586807
# Andrew Stanton      0.277052       0.277052
# Nathan Greno        0.772336       0.772336
# Joss Whedon         2.500715       2.500715
# ...                      ...            ...
# Thomas L. Phillips       NaN            NaN
# Edward Burns        0.509333       0.509333
# Scott Smith              NaN            NaN
# Benjamin Roberds         NaN            NaN
# Daniel Hsia              NaN            NaN
#
# [1090 rows x 2 columns]

# %% [markdown]
# # [Ex. 4] Une question d'entretien
#
#
# Les questions suivantes ont été posées au cours de plusieurs entretiens pour des postes de Junior Data Scientists au sein d'une start-up parisienne :
#
# > On dispose d'un historique de ventes sur un site de ecommerce qui peut être résumé dans le fichier CSV suivant :
#
# |        timestamp | customer_id | product_id | quantity | price | revenue |
# |-----------------:|------------:|-----------:|---------:|------:|--------:|
# | 2022/12/27 13:05 |        1986 |       3456 |        4 |     5 |      20 |
# | 2022/12/27 13:05 |        1986 |       3459 |        3 |     6 |      18 |
# | 2022/12/27 13:06 |       24501 |       1242 |        2 |     4 |       8 |
# | 2022/12/27 13:12 |       48285 |       3424 |        4 |    25 |     100 |
# | 2022/12/27 13:14 |        2422 |       3456 |       10 |     5 |      50 |
# |              ... |         ... |        ... |      ... |   ... |     ... |
#
#
# - timestamp (datetime)
# - customer_id (int)
# - product_id (int)
# - quantity (int)
# - price (int)
# - revenue (int)
#
# Pour chaque transaction (ie une ligne dans le fichier) ci-dessus :
# - 1. Ecrire qui une fonction qui prend en entrée la DataFrame des transactions et l'index d'une ligne (transaction) et renvoie True si la transaction a un chiffre d'affaire (colonne `revenue`) qui est dans le top 25% des transactions de la journée. Utiliser cette fonction pour flaguer ces transactions.
#
#
# - 2. Même question mais avec le mois en cours à la place de la journée

# %%
# Méthode 1 / variante A

# On veut constituer une liste qui contient les indexes de toutes les lignes dans le top 25%
# Liste des valeurs unique des journées (pas des les jours + heures, seulement les jours)
## dates = df. ....

df = pd.read_csv("../data/transactions/data.csv")

df['timestamp'] = pd.to_datetime(df["timestamp"])

dates = sorted(df["timestamp"].dt.date.unique())

# Pour chaque date on veut récupérer les indexes du top 25
indexes_top_25p_all = []

for date in dates:
    transactions_on_date = df[df.timestamp.dt.date==date]
    transactions_on_date_top25p = transactions_on_date\
        .sort_values(
            "revenue", 
            ascending=False
        )\
        .head(int(0.25*len(transactions_on_date))) # 25 % des lignes
    # et donc pas les lignes telles que au dessus du 
    indexes_top_25p = transactions_on_date_top25p.index
    indexes_top_25p_all.extend(indexes_top_25p)

# %%
len(indexes_top_25p_all)
# Out:
# 1939

# %%
# Méthode 1 / variante B

# On veut constituer une liste qui contient les indexes de toutes les lignes dans le top 25%
# Liste des valeurs unique des journées (pas des les jours + heures, seulement les jours)
## dates = df. ....

dates = sorted(df.timestamp.dt.date.unique())

# Pour chaque date on veut récupérer les indexes du top 25
indexes_top_25p_all = []

for date in dates:
    transactions_on_date = df[df.timestamp.dt.date==date]
   
    threshold = np.percentile(transactions_on_date.revenue, 75)
    
    indexes_top_25p = transactions_on_date[
        transactions_on_date.revenue > threshold
    ].index
    
    indexes_top_25p_all.extend(indexes_top_25p)
    

## def is_in_any_daily_top_25(df, row):
##    return #......

# %%
len(indexes_top_25p_all)
# Out:
# 1877

# %%
# Méthode 2 

df["revenue"] = df["price"] * df["quantity"]
df["date"] = df.timestamp.dt.date # df.timestamp.map(lambda d: d.date)

threshold_top25p_per_date = df.groupby("date").revenue.agg(lambda serie: np.percentile(serie, 75))
threshold_top25p_per_date.hist()

df = df.sort_values("date").set_index("date").join(
    threshold_top25p_per_date.to_frame(), # transforme la série en DataFrame
    rsuffix='_threshold_top25p_daily' # suffixe sur la DataFrame de droite 
)
df = df.reset_index()
# On filtre les transactions dont le CA
# est supérieur au seuil du top25% des transactions de la journée
df = df[df.revenue >= df.revenue_threshold_top25p_daily]

# %%
len(df)
# Out:
# 2229

# %%
def my_func(df, row_index):
    return row_index in df.index
